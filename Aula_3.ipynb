# %% [markdown]
# #**Aula 3 - Correlações, causalidade e relações entre genes**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true' 
dados = pd.read_csv(url_dados, compression = 'zip')
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
dados[['g-0', 'g-8']]
# Out:
#           g-0     g-8
# 0      1.0620  0.5548
# 1      0.0743 -0.4047
# 2      0.6280  0.0065
# 3     -0.5138 -0.1321
# 4     -0.3254 -0.8789
# ...       ...     ...
# 23809  0.1394 -0.4726
# 23810 -1.3260  0.5112
# 23811  0.3942 -0.0340
# 23812  0.6660  0.4299
# 23813 -0.8598  3.0790
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)
plt.show()

# %%
sns.scatterplot(x='g-0', y='g-8', data=dados)

plt.show()

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'})
plt.show()

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento', row='tempo')
plt.show()

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np
corr = dados.loc[:,'g-0':'g-50'].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()
mask = np.triu(np.ones_like(corr_celular, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #**Desafio 01: Criar tabelas de frequência com pandas.groupby()**

# %%
com_droga = dados[dados['tratamento']=='com_droga'].groupby(['dose','tempo']).count()['tratamento'] #agrupando os dados por dose e por tempo e realizando a contagem dos dados

# %%
com_controle = dados[dados['tratamento']=='com_controle'].groupby(['dose','tempo']).count()['tratamento'] #agrupando os dados por dose e por tempo e faz a contagem dos dados

# %%
com_droga
# Out:
# dose  tempo
# D1    24       3585
#       48       4011
#       72       3600
# D2    24       3581
#       48       3591
#       72       3580
# Name: tratamento, dtype: int64

# %%
com_controle
# Out:
# dose  tempo
# D1    24       301
#       48       343
#       72       307
# D2    24       305
#       48       305
#       72       305
# Name: tratamento, dtype: int64

# %% [markdown]
# #**Desafio 02: Normalizar o crosstab pela coluna.**

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# #**Desafio 03: Explorar outros agregadores.**

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-8'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.378453  -0.200714
#      48         0.256508  -0.320235
#      72         0.119413  -0.274481
# D2   24         0.544010  -0.122004
#      48         0.591717  -0.260450
#      72         0.501499  -0.251460

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-8'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -1.314      -10.0
#      48           -2.686      -10.0
#      72           -1.912      -10.0
# D2   24           -4.064      -10.0
#      48           -2.036      -10.0
#      72           -2.316      -10.0

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-8'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.419      6.578
#      48            3.702      7.848
#      72            2.499      8.887
# D2   24            2.661      4.965
#      48            5.615      5.491
#      72            3.431      5.548

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-8'], aggfunc='last')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           0.1388     0.4299
#      48           1.4260     0.4879
#      72           1.2610     3.0790
# D2   24           1.0800     0.5112
#      48          -0.0340     0.0486
#      72           0.1878    -0.0948

# %% [markdown]
# #**Desafio 04: Explorar o melt.**

# %%
pd.melt(dados,id_vars=['dose'],value_vars=['g-8'])
# Out:
#       dose variable   value
# 0       D1      g-8  0.5548
# 1       D1      g-8 -0.4047
# 2       D1      g-8  0.0065
# 3       D1      g-8 -0.1321
# 4       D2      g-8 -0.8789
# ...    ...      ...     ...
# 23809   D2      g-8 -0.4726
# 23810   D2      g-8  0.5112
# 23811   D2      g-8 -0.0340
# 23812   D1      g-8  0.4299
# 23813   D1      g-8  3.0790
#
# [23814 rows x 3 columns]

# %% [markdown]
# #**Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.**

# %%
corr = dados.loc[:,'g-0':'c-99'].corr()
corr_celular_genes = corr.loc['g-0':'g-50','c-0':'c-50']
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_celular_genes, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.lmplot(data=dados, x='g-0', y='c-0', line_kws={'color': 'red'})
plt.show()

# %%
sns.lmplot(data=dados, x='g-1', y='c-22', line_kws={'color': 'red'})
plt.show()

# %% [markdown]
# #**Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)**

# %%
corr_genes = dados.loc[:,'g-0':'g-50'].corr()
#Cria uma matriz de True na dimensão do dataframe de correlação
np.ones_like(corr_genes, dtype=bool)
#Cria uma máscara para o triângulo superior
mask = np.triu(np.ones_like(corr_genes, dtype=bool))
#Cria uma paleta de cores com o Azul para correlações negativas e e Laranja para as positivas
cmap = sns.diverging_palette(h_neg=220, h_pos=20, as_cmap=True)
#Desenha um mapa de calor aplicando a mascara e utilizando a paleta de cores.
# Comando equivalete ao plt.figure com a diferença que separa entre figura e eixos
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr_genes, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.2, cbar_kws={"shrink": .5})

# %% [markdown]
# #**Desafio 07: Resumo do que você aprendeu com os dados**
#
# crosstab;
#
# scatterplot;
#
# correlações;
#
# lmplot;
#
# como plotar e interpretar a correlação;
#
# heatmap;
