# %%
import pandas as pd #importando a biblioteca pandas e atribuindo um apelido a váriavel da biblioteca
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true' #pegando a url da base de dados e atribuindo a uma variável
dados = pd.read_csv(url_dados, compression = 'zip') #descompactando o arquivo zipado da base de dados e atribuindo a tabela à variável de "dados"
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head() #printando as primeiras linhas da tabela
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape #printando quantidade de linhas e colunas da tabela (L, C)
# Out:
# (23814, 877)

# %%
dados['tratamento'] #listando todas as células da coluna "tratamento"
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #listando todos os valores que aparecem na coluna "tratamento"
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique() #listando todos os valores que aparecem na coluna "tempo"
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique() #listando todos os valores que aparecem na coluna "dose"
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique() #listando todos os valores que aparecem na coluna "droga"
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['tratamento'].value_counts() #contando a quantidade de objetos de determinada classe presentes na coluna "tratamento"
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts() #contando a quantidade de objetos de determinada classe presentes na coluna "dose"
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['dose'].value_counts(normalize = True) #proporção dos dados da coluna "dose"
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie() #plotando um gráfico de pizza com base na coluna selecionada

# %%
dados['tempo'].value_counts().plot.pie() #plotando um gráfico de pizza com base na coluna selecionada

# %%
dados['tempo'].value_counts().plot.bar() #plotando um gráfico de barras com base na coluna selecionada

# %%
dados_filtrados = dados[dados['g-0'] > 0] #filtrando a tabela para aparecer somente as linhas em que g-0 é maior que zero.
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 01 - Investigar por que a classe *tratamento* é tão desbalanceada.
# Resposta: para um estudo clínico randomizado, o ideal é que o grupo de controle tenha no mínimo o mesmo tamanho dos ensaios que de fato utilizaram a droga.
# Todas as drogas são destinadas ao tratamento da mesma comorbidade.
# Cada droga é um estudo clínico diferente, ou seja, o grupo de controle se repete para cada droga.
# Com as premissas acima, temos que o grupo de controle chega a ser mais que o dobro para cada ensaio clínico, dando assim segurança no estudo das drogas.
#
# fonte: https://moodle.ufsc.br/pluginfile.php/821909/mod_resource/content/0/WEYNE%20-%20Determina%C3%A7%C3%A3o%20do%20tamanho%20da%20amostra%20EM%20PESQUISAS%20EXPERIMENTAIS%20-%202004.pdf

# %% [markdown]
# ###Desafio 02 - Plotar as 5 últimas linhas da tabela.

# %%
dados.tail(5) #desafio 2 - cumprido!
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03 - Proporção das classes *tratamento*.

# %%
#desafio 3 - cumprido!
dados['tratamento'].value_counts(normalize = True) #proporção dos dados da coluna "tratamento"
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ###Desafio 04 - Quantos tipos de droga foram investigados?

# %%
#desafio 4 - cumprido!
print(len(dados['droga'].value_counts()), "tipos de droga foram investigados")
# Out:
# 3289 tipos de droga foram investigados

# %% [markdown]
# ###Desafio 05 - Procurar na documentação o método query(pandas).

# %%
#desafio 5 - cumprido!
dados.query('dose == "D1"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23807  id_fff7e6992  com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %% [markdown]
# ###Desafio 06 - Renomear as colunas tirando o hífen.

# %%
#desafio 6 - cumprido!
dados.columns = dados.columns.str.replace('-', '')
dados.head(10)
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 5  id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 8  id_00224bf20  com_droga     48   D1  ... -0.1167 -0.1241 -0.6420  0.5543
# 9  id_0023f063e  com_droga     48   D2  ... -0.8745 -0.2716  0.0189 -2.0000
#
# [10 rows x 877 columns]

# %% [markdown]
# ###Desafio 07 - Deixar os gráficos bonitões. (matplotlib.pyplot)

# %%
#desafio 7 - cumprido!
import matplotlib.pyplot as plt
dados['tempo'].value_counts().plot.bar(color=['red','green','yellow'])
font = {'family':'sans-serif','color':'Black','size':18}
plt.title('Tempo', fontdict=font)
plt.xlabel('Horas',fontsize=13)
plt.xticks(rotation=0)
plt.ylabel('Quantidade', fontdict=font)
# Out:
# Text(0, 0.5, 'Quantidade')

# %% [markdown]
# ###Desafio 08 - Resumo do que aprendi com os dados.
# Usar o Google Colaboratoty;
#
# Linkar o GitHub com o Google Colab;
#
# Leitura e descompactação de base de dados utilizando a biblioteca Pandas;
#
# Leitura de valores de uma única coluna;
#
# Filtragem e contagem de dados de uma determinada coluna;
#
# Medir as dimensões da tabela;
#
# Verificar a proporção dos dados;
#
# Plotar gráficos e personalizá-los.
